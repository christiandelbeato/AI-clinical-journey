# %% [markdown]
# <a href="https://colab.research.google.com/github/christiandelbeato/AI-clinical-journey/blob/main/00_Data_loading.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive
